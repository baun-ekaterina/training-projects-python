# %% [markdown]
# # Исследование причин убыточности развлекательного приложения

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных,-предобработка" data-toc-modified-id="Обзор-данных,-предобработка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных, предобработка</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных,-общая-информация-о-таблицах" data-toc-modified-id="Загрузка-данных,-общая-информация-о-таблицах-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка данных, общая информация о таблицах</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Вывод-по-шагу-&quot;Обзор-данных,-предобработка&quot;" data-toc-modified-id="Вывод-по-шагу-&quot;Обзор-данных,-предобработка&quot;-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Вывод по шагу "Обзор данных, предобработка"</a></span></li></ul></li><li><span><a href="#Ввод-функций-для-расчета,-анализа-и-визуализации-метрик" data-toc-modified-id="Ввод-функций-для-расчета,-анализа-и-визуализации-метрик-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Ввод функций для расчета, анализа и визуализации метрик</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-профилей-с-CAC" data-toc-modified-id="Функция-для-создания-профилей-с-CAC-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания профилей с CAC</a></span></li><li><span><a href="#Функция-для-расчета-LTV-и-ROI" data-toc-modified-id="Функция-для-расчета-LTV-и-ROI-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчета LTV и ROI</a></span></li><li><span><a href="#Функция-для-расчета-удержания" data-toc-modified-id="Функция-для-расчета-удержания-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчета удержания</a></span></li><li><span><a href="#Функция-для-расчета-конверсии" data-toc-modified-id="Функция-для-расчета-конверсии-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчета конверсии</a></span></li><li><span><a href="#Функции-для-визуализации-метрик" data-toc-modified-id="Функции-для-визуализации-метрик-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функции для визуализации метрик</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Построение-профилей-пользователей" data-toc-modified-id="Построение-профилей-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Построение профилей пользователей</a></span></li><li><span><a href="#Анализ-пользователей-по-регионам" data-toc-modified-id="Анализ-пользователей-по-регионам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ пользователей по регионам</a></span></li><li><span><a href="#Анализ-пользователей-по-устройствам" data-toc-modified-id="Анализ-пользователей-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ пользователей по устройствам</a></span></li><li><span><a href="#Анализ-пользователей-по-каналам-привлечения" data-toc-modified-id="Анализ-пользователей-по-каналам-привлечения-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Анализ пользователей по каналам привлечения</a></span></li><li><span><a href="#Вывод-по-шагу-&quot;Исследовательский-анализ-данных&quot;" data-toc-modified-id="Вывод-по-шагу-&quot;Исследовательский-анализ-данных&quot;-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод по шагу "Исследовательский анализ данных"</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Анализ-общих-маркетинговых-расходов" data-toc-modified-id="Анализ-общих-маркетинговых-расходов-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ общих маркетинговых расходов</a></span></li><li><span><a href="#Средний-CAC-на-одного-пользователя" data-toc-modified-id="Средний-CAC-на-одного-пользователя-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Средний CAC на одного пользователя</a></span></li><li><span><a href="#Вывод-по-шагу-&quot;Маркетинг&quot;" data-toc-modified-id="Вывод-по-шагу-&quot;Маркетинг&quot;-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод по шагу "Маркетинг"</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-по-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-по-каналам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы по каналам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-по-устройствам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы по устройствам</a></span></li><li><span><a href="#Дополнительные-расчеты" data-toc-modified-id="Дополнительные-расчеты-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Дополнительные расчеты</a></span></li><li><span><a href="#Вывод-по-шагу-&quot;Оценка-окупаемости-рекламы&quot;" data-toc-modified-id="Вывод-по-шагу-&quot;Оценка-окупаемости-рекламы&quot;-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Вывод по шагу "Оценка окупаемости рекламы"</a></span></li></ul></li><li><span><a href="#Исследование-причин-низкой-окупаемости-рекламы" data-toc-modified-id="Исследование-причин-низкой-окупаемости-рекламы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследование причин низкой окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Анализ-конверсии-и-удержания-по-каналам" data-toc-modified-id="Анализ-конверсии-и-удержания-по-каналам-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Анализ конверсии и удержания по каналам</a></span></li><li><span><a href="#Анализ-конверсии-и-удержания-по-странам" data-toc-modified-id="Анализ-конверсии-и-удержания-по-странам-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Анализ конверсии и удержания по странам</a></span></li><li><span><a href="#Анализ-конверсии-и-удержания-по-устройствам" data-toc-modified-id="Анализ-конверсии-и-удержания-по-устройствам-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Анализ конверсии и удержания по устройствам</a></span></li><li><span><a href="#Вывод-по-шагу-&quot;Исследование-причин-низкой-окупаемости-рекламы&quot;" data-toc-modified-id="Вывод-по-шагу-&quot;Исследование-причин-низкой-окупаемости-рекламы&quot;-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Вывод по шагу "Исследование причин низкой окупаемости рекламы"</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Обзор данных, предобработка

# %%
# импорт библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# убрать предупреждения Pandas
import warnings
warnings.filterwarnings('ignore')

# выводить на экран все столбцы таблиц
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Загрузка данных, общая информация о таблицах

# %% [markdown]
# Загрузим данные о визитах, заказах и расходах в отдельные переменные:

# %%
# загрузка датасетов (полный путь не приводится, т.к. датасеты не размещены в открытом доступе)
visits = pd.read_csv(path1) # визиты (сессии)
orders = pd.read_csv(path2) # заказы (покупки)
costs = pd.read_csv(path3) # рекламные расходы

# %% [markdown]
# <a id='intro1'></a>
# Для изучения данных в таблицах напишем функцию, которая будет выводить фрагмент таблицы и общую информацию о ней. Дополнительно заложим в функцию приведение наименований колонок в "змеиный_регистр" и проверку на дубликаты:

# %%
# функция для вывода информации о таблице

def build_info(df, name): # на вход подаем датасет и его название
    # названия колонок переводим в нижний регистр, пробелы заменяем на _
    df.columns = df.columns.str.lower().str.replace(' ', '_') 
    
    print(f'Фрагмент таблицы {name}')
    display(df.head())
    print('*'*75)
    
    print(f'Общая информация о таблице {name}')
    print(df.info())
    print('*'*75)
    
    # проверка на дубликаты
    if df.duplicated().sum() == 0:
        print(f'В таблице {name} дубликатов строк не обнаружено')
    else:
        print(f'В таблице {name} обнаружены дубликаты строк')
    print('*'*75)

# %% [markdown]
# Последовательно применим функцию ко всем трем датасетам и изучим данные в них:

# %%
build_info(visits, 'visits')
# Out:
# Фрагмент таблицы visits
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
# ***************************************************************************
# Общая информация о таблице visits
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
# ...

# %% [markdown]
# Таблица `visits` содержит 310 тысяч строк и представляет из себя лог сервера с информацией о посещениях сайта. В таблице 6 столбцов, содержащих следующую информацию:
# * user_id — уникальный идентификатор пользователя
# * device — категория устройства пользователя
# * session_start — дата и время начала сессии
# * session_end — дата и время окончания сессии
# * channel — идентификатор рекламного источника, из которого пришел пользователь
# * region - страна пользователя.
#
# Дубликатов не обнаружено. В столбцах с датами необходимо преобразование типа данных.

# %%
build_info(orders, 'orders')
# Out:
# Фрагмент таблицы orders
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# ***************************************************************************
# Общая информация о таблице orders
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
# ***************************************************************************
# В таблице orders дубликатов строк не обнаружено
# ...

# %% [markdown]
# Таблица `orders` содержит 40 тысяч строк и хранит информацию о заказах. В таблице 3 столбца со следующуей информацией:
# * user_id — уникальный id пользователя, который сделал заказ
# * event_dt — дата и время покупки
# * revenue — выручка
#
# Дубликатов не обнаружено. В столбце с датами необходимо преобразование типа данных.

# %%
build_info(costs, 'costs')
# Out:
# Фрагмент таблицы costs
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# ***************************************************************************
# Общая информация о таблице costs
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
# ***************************************************************************
# В таблице costs дубликатов строк не обнаружено
# ***************************************************************************

# %% [markdown]
# Таблица `costs` состоит из 1,8 тыс.строк и содержит информацию о затратах на маркетинг. В ней 3 столбца, содержащих следующие данные:
# * channel — идентификатор рекламного источника
# * dt — дата
# * costs — затраты на этот рекламный источник в этот день
#
# Дубликатов не обнаружено. В столбце с датами необходимо преобразование типа данных.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# В столбцах с датами преобразуем типы данных:

# %%
# преобразование типов данных в datetime
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# ### Вывод по шагу "Обзор данных, предобработка"

# %% [markdown]
# Загружены таблицы со следующими данными:
# * лог сервера с данными о посещениях пользователей;
# * выгрузка покупок этих пользователей;
# * статистика рекламных расходов по привлечению пользователей.
#
# Этих данных достаточно для решения задач исследования.
#
# Произведена предобработка данных:
# * названия столбцов таблиц приведены к "змеиному_регистру";
# * изменены типы данных в отдельных столбцах;
# * проконтролировано отсутствие дубликатов строк в таблицах.

# %% [markdown]
# ## Ввод функций для расчета, анализа и визуализации метрик

# %% [markdown]
# ### Функция для создания профилей с CAC

# %% [markdown]
# На вход функции функции будут передаваться данные о посещениях приложения пользователями, информация об их покупках и расходы на рекламу. На выходе будем иметь таблицу, в которой по каждому пользователю будет определены параметры его первого посещения (дата, тип устроиства, регион), рекламный канал и расходы на его привлечение, а также флаг платящих пользователей (совершили хотя бы одну покупку в приложении).

# %%
# функция для создания пользовательских профилей
def get_profiles(sessions, orders, ad_costs):

    # сортируем сессии по ID пользователя и дате привлечения
    # группируем по ID и находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg({'session_start': 'first', 'device': 'first', 'region': 'first', 'channel': 'first'})
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    # по дате и каналу привлечения
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    # результаты сохраним в столбец acquisition_cost (CAC)
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # органические пользователи не связаны с данными о рекламе,
    # поэтому в столбце acquisition_cost у них значения NaN
    # заменим их на ноль, ведь стоимость привлечения равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles # возвращаем профили с CAC

# %% [markdown]
# ### Функция для расчета LTV и ROI

# %% [markdown]
# На вход функции функции будут передаваться профили пользователей, содержащие CAC, данные об их покупках, момент и горизонт анализа, список полей для возможности детализации бизнес-показателей (по каналам/странам/устройствам; по дефолту - пустой список, т.е. без разбивки). На выходе будем иметь 5 таблиц: сырые данные, таблицу LTV, таблицу динамики LTV, таблицу ROI и таблицу динамики ROI.

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days=horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']],
        on='user_id',
        how='left'
    )
    
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (result_raw['event_dt'] - result_raw['first_ts']).dt.days
    
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для расчета удержания

# %% [markdown]
# На вход функции функции будут передаваться профили пользователей, содержащие CAC, данные об посещениях, момент и горизонт анализа, список полей для возможности детализации по каналам/странам/устройствам (по дефолту - пустой список, т.е. без разбивки). На выходе будем иметь 3 таблицы: сырые данные, таблицу удержания и таблицу динамики удержания.

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days=horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    # присоединяем session_start к профилям по столбцу user_id
    result_raw = result_raw.merge(sessions[['user_id', 'session_start']], on='user_id', how='left')
    
    # вычисляем лайфтайм для каждой сессии в днях
    result_raw['lifetime'] = (result_raw['session_start'] - result_raw['first_ts']).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(index=dims, columns='lifetime', values='user_id', aggfunc='nunique')
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчета конверсии

# %% [markdown]
# На вход функции функции будут передаваться профили пользователей, содержащие CAC, данные о покупках, момент и горизонт анализа, список полей для возможности детализации по каналам/странам/устройствам (по дефолту - пустой список, т.е. без разбивки). На выходе будем иметь 3 таблицы: сырые данные, таблицу конверсии и таблицу динамики конверсии.

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функции для визуализации метрик

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 8))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации удержания для платящих пользователей

def plot_retention1(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 4))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # визуализировать будем только удержание и его динамику для платящих пользователей
    # в таблице графиков — два столбца и одна строка, две ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(1, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке — динамика удержания платящих
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 4))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Построение профилей пользователей

# %% [markdown]
# Для построения пользовательских профилей вызовем функцию `get_profiles`, передав ей все три датасета:

# %%
# получаем профили пользователей
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts  device         region     channel  \
# 0    599326 2019-05-07 20:58:57     Mac  United States    FaceBoom
# 1   4919697 2019-07-09 12:46:07  iPhone  United States    FaceBoom
# 2   6085896 2019-10-01 09:58:33  iPhone         France     organic
# 3  22593348 2019-08-22 21:35:48      PC        Germany  AdNonSense
# 4  31989216 2019-10-02 00:07:44  iPhone  United States     YRabbit
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Получили таблицу, в которой по каждому пользователю определены параметры его первого посещения (дата, тип устройства, регион), рекламный канал и расходы на привлечение, а также проставлен флаг платящих пользователей (совершили хотя бы одну покупку в приложении).

# %% [markdown]
# Проверим корректность работы функции, сверив данные в отдельных столбцах таблицы с исходными данными:
# * число уникальных пользователей в таблице `visits` должно быть равно количеству строк в таблице `profiles`;
# * число уникальных пользователей в таблице `orders` должно быть равно количеству строк из таблицы `profiles` с флагом платящего пользователя;
# * сумма рекламных затрат в таблице `costs` должна быть равна сумме удельных затрат на каждого пользователя в таблице `profiles`
#
# Примечание: В общем случае, второе и третье условия могут и не выполняться, если исходные данные по покупкам и рекламным затратам были бы даны за произвольный период, не соответствующий периоду привлечения пользователей, но исходим из условий ТЗ, согласно которым все таблицы содержат данные из одного временного интервала.

# %%
visits['user_id'].nunique() == len(profiles)
# Out:
# True

# %%
orders['user_id'].nunique() == len(profiles.query('payer == True'))
# Out:
# True

# %%
costs['costs'].sum().round() == profiles['acquisition_cost'].sum().round()
# Out:
# True

# %% [markdown]
# Все условия проверки истинны, значит таблица профилей сформирована корректно.

# %% [markdown]
# Определим минимальную и максимальную даты привлечения пользователей:

# %%
profiles['first_ts'].min(), profiles['first_ts'].max()
# Out:
# (Timestamp('2019-05-01 00:00:41'), Timestamp('2019-10-27 23:59:04'))

# %% [markdown]
# Пользователи привлекались за период с 1 мая по 27 октября 2019 года, что соответствует описанию в ТЗ.

# %% [markdown]
# ### Анализ пользователей по регионам

# %% [markdown]
# <a id='intro2'></a>
# Создадим функцию для вывода однотипных сводных таблиц в группировке по разным индексам:

# %%
def build_pivot(index):
    # создание сводной таблицы
    table = profiles.groupby(index).agg({'user_id': 'nunique', 'payer': ['sum','mean']})
    # переименование столбцов
    table.columns = ['total_users', 'payers', 'conversion_to_payers']
    # расчет доли платящих пользователей группы в общем кол-ве платящих пользователей
    table['payers_share'] = table['payers'] / table['payers'].sum()
    
    return table.sort_values(by='payers', ascending=False) \
                .style.format({'conversion_to_payers': '{:.2%}', 'payers_share': '{:.0%}'})

# %% [markdown]
# Выясним, из каких стран пользователи приходят в приложение, и на какую страну приходится больше всего платящих пользователей:

# %%
build_pivot('region')
# Out:
# <style  type="text/css" >
# </style><table id="T_16baf_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_users</th>        <th class="col_heading level0 col1" >payers</th>        <th class="col_heading level0 col2" >conversion_to_payers</th>        <th class="col_heading level0 col3" >payers_share</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_16baf_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_16baf_row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_16baf_row0_col1" class="data row0 col1" >6902</td>
#                         <td id="T_16baf_row0_col2" class="data row0 col2" >6.90%</td>
# ...

# %% [markdown]
# Приложением Procrastinate Pro+ пользуются клиенты из США, Великобритании, Франции и Германии, при этом на США приходится 78% платящих пользователей по всем странам, а на долю остальных стран приходится по 7-8% платящих пользователей.
#
# Максимальная конверсия в платящих пользователей внутри страны - 7% от общего количества - также приходится на США, в остальных странах покупки в приложении осуществляют 4% от общего количества пользователей.

# %% [markdown]
# ### Анализ пользователей по устройствам

# %% [markdown]
# Выясним, какими устройствами пользуются клиенты, и какие устройства предпочитают платящие пользователи:

# %%
build_pivot('device')
# Out:
# <style  type="text/css" >
# </style><table id="T_63a3d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_users</th>        <th class="col_heading level0 col1" >payers</th>        <th class="col_heading level0 col2" >conversion_to_payers</th>        <th class="col_heading level0 col3" >payers_share</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_63a3d_level0_row0" class="row_heading level0 row0" >iPhone</th>
#                         <td id="T_63a3d_row0_col0" class="data row0 col0" >54479</td>
#                         <td id="T_63a3d_row0_col1" class="data row0 col1" >3382</td>
#                         <td id="T_63a3d_row0_col2" class="data row0 col2" >6.21%</td>
# ...

# %% [markdown]
# Устанавливают приложение Procrastinate Pro+ владельцы разных устройств, при этом 38% платящих пользователей предпочитают iPhone, 22-23% - Android и Mac, PC наименее популярен - 17% всех платящих пользователей.
#
# Доля платящих пользователей среди владельцев каждого типа устройств, установивших приложение, примерно одинакова: около 6% от общего количества пользователей iPhone, Android и Mac и 5% пользователей PC совершают покупки в приложении.

# %% [markdown]
# ### Анализ пользователей по каналам привлечения

# %% [markdown]
# Изучим рекламные источники привлечения клиентов и определим каналы, из которых пришло больше всего платящих пользователей:

# %%
build_pivot('channel')
# Out:
# <style  type="text/css" >
# </style><table id="T_459f3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_users</th>        <th class="col_heading level0 col1" >payers</th>        <th class="col_heading level0 col2" >conversion_to_payers</th>        <th class="col_heading level0 col3" >payers_share</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_459f3_level0_row0" class="row_heading level0 row0" >FaceBoom</th>
#                         <td id="T_459f3_row0_col0" class="data row0 col0" >29144</td>
#                         <td id="T_459f3_row0_col1" class="data row0 col1" >3557</td>
#                         <td id="T_459f3_row0_col2" class="data row0 col2" >12.20%</td>
# ...

# %% [markdown]
# Привлечение пользователей шло по 10 каналам, при этом рекламными источниками, которые замотивировали наибольшее количество пользователей посетить интернет-магазин, являются FaceBoom и TipTop: на них приходится 40% и 21% всех платящих пользователей, при этом через канал FaceBoom в абсолютном выражении пришло почти в 2 раза больше пользователей. Еще 13% платящих пользователей являются органическими, т.е. начали использовать приложение самостоятельно. На долю остальных каналов привлечения приходится 2-5% от всех платящих пользователей.
#
# Конверсия из подключившихся пользователей в платящих для каналов-лидеров FaceBoom и TipTop составляет 12% и 10% соответственно. Также высокую долю в 10-11% платящих пользователей можно наблюдать среди клиентов, пришедших через каналы AdNonSense и lambdaMediaAds, однако в целом эти каналы обеспечивают небольшой общий приток клиентов и не могут считаться лидерами.

# %% [markdown]
# ### Вывод по шагу "Исследовательский анализ данных"

# %% [markdown]
# Сформирована статистика по странам, устройствам и рекламным каналам, которые присутствуют в профилях пользователей приложения Procrastinate Pro+:
# * 78% платящих пользователей - жители США; конверсия пользователей из неплатящих в платящие в США составляет 7%, в остальных странах 4% от общего количества установивших приложение;
# * 38% платящих пользователей предпочитают iPhone; доля платящих пользователей среди всех клиентов-владельцев каждого типа устройств примерно одинакова и составляет около 6%;
# * 40% платящих пользователей установили приложение под влиянием рекламного канала FaceBoom, еще 21% пришли из TipTop - это каналы-лидеры. Конверсия из подключенных в платящих по этим каналам достаточно высока: 12% и 10% соответственно.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Анализ общих маркетинговых расходов

# %% [markdown]
# Для исследования общих расходов на маркетинг обратимся к данным таблицы `costs`, в которой отражения даты проведения рекламных кампаний, рекламные источники и стоимость рекламы:

# %%
costs['costs'].sum().round(2)
# Out:
# 105497.3

# %% [markdown]
# Общая сумма рекламных расходов на маркетинг за период с 1 мая по 27 октября 2019 года составила $105497.3, посмотрим, как эти траты распределены по источникам:

# %%
# сводная таблица с агрегацией расходов по каналам привлечения
costs_grouped = (
    costs.groupby('channel')
    .agg({'costs': 'sum'})
    .sort_values(by='costs', ascending=False)
    .rename(columns={'costs': 'total_costs'})
    
)

# ввод столбца с расчетом доли расходов отдельного канала в общих расходах
costs_grouped['share'] = (costs_grouped['total_costs'] / costs_grouped['total_costs'].sum()).round(2)

costs_grouped.style.format({'total_costs': '{:.2f}', 'share': '{:.0%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_7fac5_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_costs</th>        <th class="col_heading level0 col1" >share</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7fac5_level0_row0" class="row_heading level0 row0" >TipTop</th>
#                         <td id="T_7fac5_row0_col0" class="data row0 col0" >54751.30</td>
#                         <td id="T_7fac5_row0_col1" class="data row0 col1" >52%</td>
#             </tr>
#             <tr>
#                         <th id="T_7fac5_level0_row1" class="row_heading level0 row1" >FaceBoom</th>
#                         <td id="T_7fac5_row1_col0" class="data row1 col0" >32445.60</td>
# ...

# %% [markdown]
# Из таблицы видим, что 52% всего рекламного бюджета за период было потрачено на оплату рекламы в канале TipTop. Еще 31% маркетинговых расходов сформированы по каналу FaceBoom. В абсолютном выражении вложения компании в канал TipTop в 1,7 раз выше, чем в канал FaceBoom, хотя приток платящих пользователей через этот канал был, наоборот, меньше в 2 раза.
#
# На остальные 8 рекламных каналов потрачено 1-5% от общей суммы расходов на маркетинг.

# %% [markdown]
# Для визуализации динамики рекламных расходов введем в таблицу `costs` дополнительный столбец с месяцем проведения рекламных кампаний и объединим каналы с наименьшими затратами в группу 'others'. Затем визуализируем динамику общих рекламных расходов и расходов по каналам:

# %%
# новый столбец с месяцем
costs['month'] = costs['dt'].astype('datetime64[M]').dt.date

# функция для категоризации рекламных каналов
def channel_add(channel):
    if channel not in ['TipTop', 'FaceBoom', 'organic']:
        channel = 'others'
    else:
        channel=channel
    return channel

# столбец с дополнительным обозначением канала с учетом категории others
costs['channel_add'] = costs['channel'].apply(channel_add)

# построение столбчатой диаграммы
fig = plt.figure(figsize=(15,7))

ax0 = fig.add_subplot(2, 1, 1)
ax1 = fig.add_subplot(2, 1, 2)

sns.lineplot(x='month', y='costs', data = costs.groupby('month').agg({'costs': 'sum'}).reset_index(), ax=ax0)

sns.barplot(x='month', y='costs', hue='channel_add', palette='Blues',
            data = costs.groupby(['month', 'channel_add']).agg({'costs': 'sum'}).reset_index(), ax=ax1)

ax0.set_title('Ежемесячная динамика общих рекламных расходов')
ax1.set_title('Ежемесячная динамика рекламных расходов по каналам')

ax0.set_xlabel('Месяц')
ax1.set_xlabel('Месяц')

ax0.set_ylabel('Расходы, $')
ax1.set_ylabel('Расходы, $')

ax1.set_xticklabels(['2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10'])
ax1.legend(title='канал')

fig.tight_layout()
plt.show()

# %% [markdown]
# Из графиков видимо, что общая сумма расходов на рекламу увеличивалась каждый месяц, падение в октябре может быть связано как с реальным уменьшением объемов вложений в рекламу, так и с тем, что данные за этот месяц неполные (до 27 октября 2019).
#
# Можно отметить, что в рекламу приложения на канале FaceBoom и прочих каналах компания ежемесячно вкладывает примерно одинаковые суммы денег, а рост рекламных расходов обусловлен ростом вложений в рекламу на канале TipTop.

# %% [markdown]
# ### Средний CAC на одного пользователя

# %% [markdown]
# Для расчета средней стоимости привлечения одного клиента - Customer Acqusition Cost (CAC) - будем использовать столбец `acquisition_cost` из таблицы `profiles`: он сформирован путем деления общих рекламных расходов за конкретный день проведения рекламных компаний в каждом канале на количество новых пользователей, которых удалось привлечь в этот же день из этого же канала.
#
# Дополнительно, для расчета величин только по "платным" пользователям, которые появились в приложении благодаря рекламным каналам, создадим новый датафрейм:

# %%
# датафрейм по "платным" пользователям с отсечением органических
profiles_paid = profiles.loc[~(profiles['channel']=='organic')]

# %% [markdown]
# Сначала рассчитаем средний CAC на одного пользователя для всего проекта за весь рассматриваемый период:

# %%
print(f"Число привлеченных пользователей: {len(profiles)} чел.")
print(f"   в т.ч. 'платные' пользователи: {len(profiles_paid)} чел.")
print(f"Сумма инвестиций в маркетинг ${profiles['acquisition_cost'].sum().round(2)}")
print(f"Средний CAC на одного пользователя: ${profiles['acquisition_cost'].mean().round(2)}")
print(f"   в т.ч. на одного 'платного' пользователя: ${profiles_paid['acquisition_cost'].mean().round(2)}")
# Out:
# Число привлеченных пользователей: 150008 чел.
#    в т.ч. 'платные' пользователи: 93569 чел.
# Сумма инвестиций в маркетинг $105497.3
# Средний CAC на одного пользователя: $0.7
#    в т.ч. на одного 'платного' пользователя: $1.13

# %% [markdown]
# Теперь рассчитаем средний CAC для каждого канала привлечения:

# %%
cac_channel = (
                profiles.pivot_table(index='channel', values='acquisition_cost', aggfunc='mean')
                        .rename(columns={'acquisition_cost': 'CAC'}) \
                        .sort_values(by='CAC', ascending=False)
)
cac_channel.style.format('{:.2f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_27ca3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CAC</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_27ca3_level0_row0" class="row_heading level0 row0" >TipTop</th>
#                         <td id="T_27ca3_row0_col0" class="data row0 col0" >2.80</td>
#             </tr>
#             <tr>
#                         <th id="T_27ca3_level0_row1" class="row_heading level0 row1" >FaceBoom</th>
#                         <td id="T_27ca3_row1_col0" class="data row1 col0" >1.11</td>
#             </tr>
#             <tr>
#                         <th id="T_27ca3_level0_row2" class="row_heading level0 row2" >AdNonSense</th>
#                         <td id="T_27ca3_row2_col0" class="data row2 col0" >1.01</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Из таблицы видим, что за период с 1 мая по 27 октября 2019 года дороже всего для компании стоило привлечение пользователей из канала TipTop $2.8 на человека, тогда как пользователь, привлеченный через второй канал-лидер - FaceBoom - требовал вложений в 2.5 раза меньше. При этом, как мы помним, компания ежемесячно наращивала объем вложений именно в канал TipTop - вложения в него были в 1.7 раз больше, чем в FaceBoom, при этом число привлеченных платящих пользователей из этого канала оказалось в 2 раза меньше.
#
# Также из таблицы видно, что средний CAC для других источников трафика составляет $0.21 - 1.01, при этом затраты на привлечение органических пользователей нулевые.

# %% [markdown]
# Дополнительно посмотрим на график истории изменения CAC по каналам привлечения с укрупнением каналов по группам, как это делали при анализе общих маркетинговых расходов:

# %%
# столбец с дополнительным обозначением канала с учетом категории others
profiles['channel_add'] = profiles['channel'].apply(channel_add)

# %%
# строим график истории изменений CAC по каналам привлечения

profiles.pivot_table(
    index='dt', columns='channel_add', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(15, 5))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.legend(title='канал')
plt.show()

# %% [markdown]
# Из этого графика видно, что CAC по каналу TipTop растет практически каждый месяц, тогда как по каналу FaceBoom остается на условно-постоянном уровне, а совокупно по всем прочим каналам даже единоразово снижается к июню 2019г.

# %% [markdown]
# ### Вывод по шагу "Маркетинг"

# %% [markdown]
# * За период с 1 мая по 27 октября 2019 года на рекламу приложения Procrastinate Pro+ потрачено $105 тыс., при этом 52% этих расходов вложены в рекламный канал TipTop, еще 31% - в канал FaceBoom, на долю остальных 8 каналов привлечения приходится 17% рекламного бюджета. В абсолютном выражении вложения компании в канал TipTop в 1.7 раз выше, чем в канал FaceBoom, хотя приток платящих пользователей через этот канал был, наоборот, меньше в 2 раза.
#
# * Общая сумма расходов на рекламу увеличивалась каждый месяц, и это обусловлено ростом вложений в рекламу на канале TipTop при условно-постоянных ежемесячных вложениях в остальные каналы.
#
# * В среднем, на привлечение одного пользователя за весь период исследования компания тратила $0.7.
#
# * Один "платный" пользователь, пришедший через рекламный канал, в среднем, обошелся компании в $1.13.
#
# * Дороже всего компании обходилось привлечение пользователей из канала TipTop $2.8 на человека, тогда как пользователь, привлеченный через второй канал-лидер - FaceBoom - требовал вложений в 2.5 раза меньше.
#
# * CAC по каналу TipTop растет каждый месяц, тогда как по другим каналам остается примерно одинаковым. Необходимо разобраться, насколько обоснованным являлось вложение более 50% рекламного бюджета именно в этот канал привлечения и ежемесячная готовность компании поддерживать увеличивающиеся тарифы с учетом всех вышеописанных наблюдений.

# %% [markdown]
# ## Оценка окупаемости рекламы

# %% [markdown]
# Установим момент и горизонт анализа: предположим, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.

# %%
observation_date = datetime(2019, 11, 1).date() # момент анализа
horizon_days = 14  # горизонт анализа

# %% [markdown]
# Для расчета метрик будем брать данные таблицы `profiles_paid`, в которой отсечены органические пользователи, т.к. они окупаются по умолчанию, а их присутствие в расчете с детализацией, например, по странам или устройствам исказит значение ROI: выручка от их покупок будет увеличивать LTV (числитель), при этом CAC (знаменатель) по ним нулевой, и ROI по группе будет искажено.

# %% [markdown]
# ### Анализ общей окупаемости рекламы

# %% [markdown]
# Рассчитаем общие метрики LTV, CAC и ROI, вызвав функции `get_ltv()`:

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_paid, orders, observation_date, horizon_days)

# %% [markdown]
# Визуализируем метрики с помощью функций `plot_ltv_roi`:

# %%
# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=7)

# %% [markdown]
# По графикам можно сделать следующие выводы:
# * поведение кривой LTV совпадает с ожидаемым: она плавно растет и не снижается;
# * в динамике LTV пользователей на 14-й день прослеживается влияние сезонного фактора, но в целом показатель стабилен, т.е. "качество" пользователей не ухудшается на рассматриваемом временном интервале их привлечения;
# * CAC постоянно растет, наблюдаются многократные скачки - необходимо детельнее исследовать этот вопрос в следующих шагах;
# * ROI в конце ожидаемого двухнедельного периода полной окупаемости затрат на привлечение пользователей достигает всего 80%, т.е. реклама не окупается;
# * динамика ROI пользователей на 14-й день показывает, что рекламные затраты окупались только по пользователям, привлеченным в мае и отдельных днях июня, а для остальных когорт ROI постоянно снижается.
#
# Таким образом, компания постоянно увеличивает затраты на привлечение одного пользователя, и при сохранении "качества" клиентов (LTV пользователей на 14-й день не ухудшается) ROI для последующих когорт постоянно снижается - реклама не окупается.

# %% [markdown]
# ### Анализ окупаемости рекламы по каналам

# %% [markdown]
# Рассчитаем и визуализируем LTV, CAC и ROI в разбивке по рекламным каналам. Поскольку каналов много, то визуализировать будем по группам каналов для лучшей читаемости графиков:

# %%
# задаем список каналов
channel_list = [['FaceBoom', 'TipTop'],
                ['AdNonSense', 'YRabbit', 'MediaTornado','RocketSuperAds'],
                ['LeapBob', 'WahooNetBanner', 'OppleCreativeMedia', 'lambdaMediaAds']
               ]

for i in range(len(channel_list)):
    print(f'Визуализация метрик для каналов {channel_list[i]}')
    # считаем LTV и ROI в разбивке по каналам
    ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
        profiles_paid.loc[profiles_paid['channel'].isin(channel_list[i])],
        orders,
        observation_date,
        horizon_days,
        dimensions=['channel']
    )
    # строим графики в разбивке по каналам
    plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=7)
    print('')
# Out:
# Визуализация метрик для каналов ['FaceBoom', 'TipTop']
# Визуализация метрик для каналов ['AdNonSense', 'YRabbit', 'MediaTornado', 'RocketSuperAds']
# Визуализация метрик для каналов ['LeapBob', 'WahooNetBanner', 'OppleCreativeMedia', 'lambdaMediaAds']

# %% [markdown]
# По графикам можно сделать следующие выводы:
# * "качество" пользователей, привлеченных по всем каналам, не ухудшается, но и не улучшается (а это могло бы положительно отразиться на ROI);
# * CAC по каналу TipTop постоянно растет: компания ежемесячно увеличивает рекламный бюджет по этой статье. При этом по остальным каналам стоимость привлечения пользователей почти постоянна, а по каналам RocketSuperAds и YRabbit видны периодические снижения;
# * ROI по каналам-лидерам в конце ожидаемого двухнедельного периода полной окупаемости не достигает уровня окупаемости, при этом канал TipTop более убыточен в сравнении с FaceBoom. Также на 14-дневном интервале убыточным является канал AdNonSense. Рекламные затраты на остальные каналы окупаются на 14-дневном интервале;
# * динамика ROI пользователей на 14-й день по каналам-лидерам показывает, что затраты на привлечение через канал FaceBoom стабильно ниже уровня окупаемости, но остаются постоянными для всех когорт. Для канала TipTop окупаемость наблюдалась только у пользователей, привлеченных в первой половине мая и в отдельные дни июня, для остальных когорт ROI по этому каналу постоянно снижается. По остальным каналам ROI относительно стабилен для всех когорт пользователей и, в среднем, находится выше линии окупаемости, за исключением убыточного канала AdNonSense.
#
# Таким образом, оба основных канала привлечения пользователей убыточны, при этом компания соглашается на увеличение стоимости привлечения по каналу TipTop.

# %% [markdown]
# ### Анализ окупаемости рекламы по странам

# %% [markdown]
# Рассчитаем и визуализируем LTV, CAC и ROI в разбивке по странам.

# %%
# считаем LTV и ROI в разбивке по странам
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_paid, orders, observation_date, horizon_days, dimensions=['region'])

# строим графики в разбивке по странам
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=7)

# %% [markdown]
# По графикам можно сделать следующие выводы:
# * "качество" пользователей, привлеченных во всех странах, не ухудшается;
# * CAC по США постоянно растет, тогда как по остальным странам с июня, вероятно, были пересмотрены условия договоров с рекламными каналами, т.к. САС единоразово снизился и далее остается постоянным;
# * ROI в конце двухнедельного периода для пользователей из США не достигает уровня окупаемости, при этом по остальным странам реклама окупается;
# * динамика ROI на 14-й день для когорт пользователей из США снижается, находясь выше уровня окупаемости только у пользователей, привлеченных в первой половине мая. По остальным странам ROI в динамике, в среднем, находится выше уровня окупаемости по всем когортам, при этом в Великобритании наблюдаются всплески ROI в середине июля и августа выше уровня 300% (это предмет для дополнительного исследования, выходящий за рамки текущего анализа).
#
# Таким образом, реклама в США убыточна, при этом компания продолжает ежемесячно наращивать рекламные расходы для привлечения клиентов именно в этой стране.

# %% [markdown]
# ### Анализ окупаемости рекламы по устройствам

# %% [markdown]
# Рассчитаем и визуализируем LTV, CAC и ROI в разбивке по устройствам.

# %%
# считаем LTV и ROI в разбивке по устройствам
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_paid, orders, observation_date, horizon_days, dimensions=['device'])

# строим графики в разбивке по устройствам
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=7)

# %% [markdown]
# По графикам можно сделать следующие выводы:
#
# * "качество" пользователей, пользующихся разными устройствами, не ухудшается;
# * CAC постоянно растет по всем типам устройств, что связано с общим ежемесячным увеличением рекламного бюджета;
# * ROI в конце ожидаемого двухнедельного периода достигает уровня окупаемости только по владельцам PC, пользователи остальных устройств не окупаются, при этом хуже всех окупаются владельцы iPhone и Mac, которые, вероятно, по большей части являются клиентами из США;
# * динамика ROI на 14-й день для всех когорт и всех типов устройств постоянно снижается, т.е. привлечение клиентов со временем становится стабильно дороже.

# %% [markdown]
# ### Дополнительные расчеты

# %% [markdown]
# <a id='intro3'></a>
# Мы выяснили, что реклама убыточна в тех случаях, когда привлеченный пользователь:
# * пришел по одному из трех каналов: TipTop, FaceBoom и AdNonSense
# * является жителем США
# * пользуется приложением через iPhone, Mac или Аndroid.
#
# Хочется внести ясность в эту картину и построить сводную таблицу, отражающие количество уникальных пользователей в группировке по каналам и странам:

# %%
# сводная таблица с кол-вом "платных" пользователей по каналам и странам
df = profiles_paid.pivot_table(index='channel', columns='region', values='user_id', aggfunc='nunique').fillna(0)

# добавляем средний CAC по каждому каналу для информативности
pd.concat([df, cac_channel], axis=1).sort_values(by='CAC', ascending=False).drop(index=['organic'])
# Out:
#                     France  Germany      UK  United States       CAC
# channel
# TipTop                 0.0      0.0     0.0        19561.0  2.799003
# FaceBoom               0.0      0.0     0.0        29144.0  1.113286
# AdNonSense          1366.0   1219.0  1295.0            0.0  1.008054
# lambdaMediaAds       742.0    649.0   758.0            0.0  0.724802
# WahooNetBanner      2971.0   2579.0  3003.0            0.0  0.602245
# RocketSuperAds         0.0      0.0     0.0         4448.0  0.412095
# OppleCreativeMedia  2991.0   2562.0  3052.0            0.0  0.250000
# YRabbit                0.0      0.0     0.0         4312.0  0.218975
# MediaTornado           0.0      0.0     0.0         4364.0  0.218717
# LeapBob             2988.0   2519.0  3046.0            0.0  0.210172

# %% [markdown]
# Из таблицы становится понятно, что через убыточные каналы TipTop и FaceBoom привлекаются только пользователи из США, и это максимальные объемы привлечения, при этом канал TipTop еще и самый дорогой.
#
# Канал AdNonSense работает на пользователей из всех остальных стран, кроме США, он не является основным по количеству привлеченных платных пользователей, однако является самым дорогим и обеспечивает значимый поток в каждой стране.

# %% [markdown]
# Дополнительно построим сводную таблицу, отражающую количество уникальных пользователей в группировке по устройствам и странам:

# %%
# сводная таблица с кол-вом "платных" пользователей по устройствам и странам
profiles_paid.pivot_table(index='device', columns='region', values='user_id', aggfunc='nunique').fillna(0)
# Out:
# region   France  Germany    UK  United States
# device
# Android    3313     2849  3243          12436
# Mac        1163     1020  1086          15424
# PC         4384     3797  4551           6421
# iPhone     2198     1862  2274          27548

# %% [markdown]
# Данная таблица позволяет увидеть, что во Франции, Германии и Великобритании наибольшее число "платных" пользователей используют приложение для PC, при этом для США это самый непопулярный способ использования.

# %% [markdown]
# ### Вывод по шагу "Оценка окупаемости рекламы"

# %% [markdown]
# Анализ окупаемости рекламы позволяет сделать следующие выводы:
#
# * Компания постоянно увеличивает затраты на привлечение одного пользователя, и при сохранении "качества" клиентов ROI для последующих когорт постоянно снижается - в целом, реклама не окупается.
#
# * Оба основных канала привлечения пользователей - FaceBoom и TipTop - убыточны, при этом компания ежемесячно соглашается на увеличение стоимости привлечения по каналу TipTop. Также убыточным является канал AdNonSense.
#
# * Реклама в США  убыточна, т.к. подавляющее большинство клиентов как раз и приходят из каналов TipTop и FaceBoom, при этом компания продолжает ежемесячно наращивать рекламные расходы для США (по каналу TipTop).
#
# * Владельцы iPhone, Mac и Android убыточны. Это является следствием убыточной рекламы в США - стране с максимальным кол-вом привлекаемых пользователей, каждый из которых пользуется разными типами устройств.
#
# Таким образом, анализ окупаемости рекламы позволяет сделать вывод о том, что компания ведет убыточную рекламную политику.

# %% [markdown]
# ## Исследование причин низкой окупаемости рекламы

# %% [markdown]
# На предыдущем шаге пришли к выводу о том, что рекламная политика компании убыточна. Попробуем понять в чем причина: в низкой конверсии или низком удержании пользователей.

# %% [markdown]
# ### Анализ конверсии и удержания по каналам

# %% [markdown]
# Рассчитаем и визуализируем удержание и конверсию на 14-дневном интервале с момента регистрации пользователя в разбивке по каналам. Будем использовать функции `get_conversion`, `get_retention()`, `plot_conversion` и `plot_retention1` (визуализировать удержание будем только для платящих пользователей, поскольку по неплатящим эти данные не влияют на поиск причин убыточности бизнеса).
#
# Особое внимание будем уделять анализу показателей по трем убыточным каналам 'FaceBoom', 'TipTop', 'AdNonSense'.
#
# Поскольку каналов много, то визуализировать будем по группам каналов для лучшей читаемости графиков:

# %%
# задаем список каналов
channel_list = [['FaceBoom', 'TipTop', 'AdNonSense', 'OppleCreativeMedia', 'lambdaMediaAds'],
                ['RocketSuperAds', 'LeapBob', 'WahooNetBanner', 'YRabbit', 'MediaTornado']
               ]

for i in range(len(channel_list)):
    print(f'Визуализация конверсии для каналов {channel_list[i]}')
    # считаем конверсию в разбивке по каналам
    conversion_raw, conversion_grouped, conversion_history = get_conversion(
        profiles_paid.loc[profiles_paid['channel'].isin(channel_list[i])],
        orders,
        observation_date,
        horizon_days,
        dimensions=['channel']
    )
    # строим графики в разбивке по каналам
    plot_conversion(conversion_grouped, conversion_history, horizon_days, window=7)
    print('')
# Out:
# Визуализация конверсии для каналов ['FaceBoom', 'TipTop', 'AdNonSense', 'OppleCreativeMedia', 'lambdaMediaAds']
# Визуализация конверсии для каналов ['RocketSuperAds', 'LeapBob', 'WahooNetBanner', 'YRabbit', 'MediaTornado']

# %% [markdown]
# Судя по графикам, пользователи из всех рекламных каналов конвертируются медленно: наилучшие показатели к 14-му лайфтайму у пользователей, пришедших из канала FaceBoom. Такая скорость роста кривых конверсий наводит на мысль о том, что пользователи совершают покупки только в первую неделю после подключения, т.к. после 7-го лайфтайма все кривые почти перестают расти. В динамике конверсии пользователей на 14-й день прослеживается влияние сезонного фактора, но в целом показатель стабилен, т.е. "качество" пользователей не ухудшается.

# %%
for i in range(len(channel_list)):
    print(f'Визуализация удержания для каналов {channel_list[i]}')
    # считаем удержание в разбивке по каналам
    retention_raw, retention_grouped, retention_history = get_retention(
        profiles_paid.loc[profiles_paid['channel'].isin(channel_list[i])],
        visits,
        observation_date,
        horizon_days,
        dimensions=['channel']
    )
    # строим графики в разбивке по каналам
    plot_retention1(retention_grouped, retention_history, horizon_days, window=7)
    print('')
# Out:
# Визуализация удержания для каналов ['FaceBoom', 'TipTop', 'AdNonSense', 'OppleCreativeMedia', 'lambdaMediaAds']
# Визуализация удержания для каналов ['RocketSuperAds', 'LeapBob', 'WahooNetBanner', 'YRabbit', 'MediaTornado']

# %% [markdown]
# По графикам видно, что платящие пользователи из каналов FaceBoom и AdNonSense стабильно плохо удерживаются и имеют почти нулевой показатель удержания к 14-му дню, тогда как пользователи канала TipTop удерживаются намного лучше - к 14-му дню их остается примерно на 20%, и этот показатель, в среднем, стабилен для пользователей, привлеченных в разные периоды.
#
# Также смущает прерывистость линий динамики удержания по каналу AdNonSense и прочим: это значит, что пользователи, привлеченные в отдельные периоды, в принципе не удерживаются к 14-му дню.

# %% [markdown]
# ### Анализ конверсии и удержания по странам

# %% [markdown]
# Рассчитаем и визуализируем конверсию и удержание в разбивке по странам.

# %%
# считаем конверсию в разбивке по странам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_paid,
    orders,
    observation_date,
    horizon_days,
    dimensions=['region']
)
# строим графики в разбивке по странам
plot_conversion(conversion_grouped, conversion_history, horizon_days, window=7)

# %% [markdown]
# Пользователи из всех стран конвертируются медленно, при этом наибольшую конверсию показывают пользователи из США, а у пользователей из остальных стран конверсия значительно ниже. Рост кривых конверсий по всем странам замедляется после первой недели. Показатель конверсии на 14-й день в США увеличился с июня и остался, в среднем, на стабильном уровне, тогда как по другим странам картина обратная: максимальную конверсию показывали пользователи, привлеченные в мае, затем показатель снизился.

# %%
# считаем удержание в разбивке по странам
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_paid,
    visits,
    observation_date,
    horizon_days,
    dimensions=['region']
    )
# строим графики в разбивке по странам
plot_retention1(retention_grouped, retention_history, horizon_days, window=7)

# %% [markdown]
# По графикам видно, что платящие пользователи из США удерживаются хуже остальных, причем показатель конверсии на 14-й день, в среднем, стабилен во времени для всех стран.
#
# Также смущает прерывистость линий динамики удержания по Франции, Германии и Великобритании: это значит, что пользователи, привлеченные в отдельные периоды, в принципе не удерживаются к 14-му дню.

# %% [markdown]
# ### Анализ конверсии и удержания по устройствам

# %% [markdown]
# Рассчитаем и визуализируем конверсию и удержание в разбивке по устройствам.

# %%
# считаем конверсию в разбивке по странам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles_paid,
    orders,
    observation_date,
    horizon_days,
    dimensions=['device']
)
# строим графики в разбивке по странам
plot_conversion(conversion_grouped, conversion_history, horizon_days, window=7)

# %% [markdown]
# Пользователи iPhone и Mac конвертируются лучше всего, что коррелирует с выводами предыдущего шага: большинство из них живут в США. Ниже всего конверсия у пользователей PC: возможно, есть проблемы/неудобства в платежном модуле приложения для PC. Показатели конверсии по устройствам на 14-й день относительно стабильны в течение рассматриваемого периода привлечения.

# %%
# считаем удержание в разбивке по странам
retention_raw, retention_grouped, retention_history = get_retention(
    profiles_paid,
    visits,
    observation_date,
    horizon_days,
    dimensions=['device']
    )
# строим графики в разбивке по странам
plot_retention1(retention_grouped, retention_history, horizon_days, window=7)

# %% [markdown]
# Большого разрыва в удержании пользователей по утройствам на наблюдается, отсюда можно предположить, что приложение работает нормально на всех устройствах, и технических проблем нет. Показатели удержания на 14-й день относительно стабильны по всем устройствам в течение рассматриваемого периода привлечения.

# %% [markdown]
# ### Вывод по шагу "Исследование причин низкой окупаемости рекламы"

# %% [markdown]
# Основные причины низкой окупаемости рекламы:
# * низкое удержание пользователей из США, привлеченных через канал FaceBoom, при этом по числу пользователей этот канал является лидером привлечения по США;
# * низкое удержание пользователей из других стран, привлеченных через канал AdNonSense, привлечение в котором составляет значимую долю в объемах для каждой страны;
# * пользователи из всех рекламных каналов конвертируются в платящих медленно: похоже на то, что пользователи совершают покупки только в первую неделю после подключения. При этом по сравнению с США конверсия в других странах зачительно ниже: это может быть связано с проблемами/неудобствами в платежном модуле приложения для PC, которым пользуется большинство клиентов из этих стран.
#
# Рекламному отделу необходимо разработать стимулирующие мероприятия, способствующие удержанию существующих пользователей и проработать вопрос повышения конверсии у пользователей PC.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В ходе аналитического исследования выполнены следующие задачи:
#
# 1) Сформирована статистика по странам, устройствам и рекламным каналам, которые присутствуют в профилях пользователей приложения Procrastinate Pro+: 78% платящих пользователей - жители США, которые устанавливают приложение благодаря рекламе в каналах FaceBoom и TipTop
#
# 2) Изучена динамика расходов на рекламу: за рассматриваемый период 52% рекламных расходов составляют вложения в канал TipTop, еще 31% - в канал FaceBoom. В абсолютном выражении вложения компании в канал TipTop в 1.7 раз выше, чем в канал FaceBoom, хотя приток платящих пользователей через этот канал был, наоборот, меньше в 2 раза. Общая сумма расходов на рекламу увеличивалась каждый месяц, и это обусловлено ростом вложений в рекламу на канале TipTop при условно-постоянных ежемесячных вложениях в остальные каналы.
#
# 3) Рассчитан общий CAC: в среднем, на привлечение одного пользователя компания тратила 0.7 долл. Дороже всего компании обходилось привлечение пользователей из канала TipTop - 2.8 долл. на человека, тогда как пользователь, привлеченный через второй канал-лидер - FaceBoom - требовал вложений в 2.5 раза меньше.
#
# 4) Проведен анализ окупаемости рекламы:
#
# * компания постоянно увеличивает затраты на привлечение одного пользователя канала TipTop, что вызывает рост общих рекламных трат, и при сохранении "качества" клиентов ROI для последующих когорт постоянно снижается. Реклама не окупается.
#
# * оба основных канала привлечения пользователей из США - FaceBoom и TipTop - убыточны, при этом компания ежемесячно соглашается на увеличение стоимости привлечения по каналу TipTop. Также убыточным является канал AdNonSense для пользователей из других стран.
#
# 5) Проведен анализ причин низкой окупаемости рекламы:
#
# * низкое удержание пользователей из США, привлеченных через канал FaceBoom, при этом по числу пользователей этот канал является лидером привлечения по США;
# * низкое удержание пользователей из других стран, привлеченных через канал AdNonSense, привлечение в котором составляет значимую долю в объемах для каждой страны;
# * пользователи из всех рекламных каналов конвертируются в платящих медленно: похоже на то, что пользователи совершают покупки только в первую неделю после подключения. При этом по сравнению с США конверсия в других странах зачительно ниже: это может быть связано с проблемами/неудобствами в платежном модуле приложения для PC, которым пользуется большинство клиентов из этих стран.
#
# Рекомендации рекламному отделу компании:
#
# 1) разработать стимулирующие мероприятия, способствующие удержанию существующих пользователей, привлеченных через каналы FaceBoom и AdNonSense. Надежные методы удержания существующих клиентов обеспечивают приток новых клиентов, приходящих по рекомендации друзей/знакомых, и это не требует рекламных затрат.
#
# 2) разработать мероприятия по стимулированию конверсии, уделив особое внимание проверке/доработке платежного модуля приложения для PC, которым пользуется большинство клиентов из Франции, Германии и Великобритании.
#
# 3) пересмотреть условия договорных отношений с рекламным каналом TipTop: тарифы на привлечение клиентов слишком высоки по сравнению с другими каналами, кроме этого они ежемесячно пересматриваются в сторону повышения.
#
# 4) в целях оперативного реагирования на проблемы окупаемости рекламы отделу маркетинга рекомендуется внедрить/доработать управленческую отчетность с визуализацией основных метрик и осуществлять их контроль, как минимум, на еженедельной основе.
